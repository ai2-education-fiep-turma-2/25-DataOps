# %%
from pycaret.datasets import get_data

# %% [markdown]
# ## Pycaret

# %% [markdown]
# ## Dados de teste Pycaret

# %%
import pandas as pd

# %%
data = pd.read_csv('/home/silvio/dataset/auto_final.csv')

# %% [markdown]
# ## iniciando experimento

# %%
from pycaret.regression import *
reg1 = setup(data, target = 'mpg', session_id=123, log_experiment=True, experiment_name='insurance1')

# %% [markdown]
# # comparando modelos com a base acima

# %%
best_model = compare_models(fold=5)

# %% [markdown]
# # Criando modelo

# %%
gbr = create_model('ridge')

# %% [markdown]
# # otimizando modelo

# %%
tuned_gbr = tune_model(gbr, n_iter=50, optimize = 'MAE')

# %%
tuned_gbr

# %% [markdown]
# ## plot modelo - informações gerais

# %%
plot_model(tuned_gbr)

# %% [markdown]
# ## plot erro

# %%
plot_model(tuned_gbr, plot = 'error')

# %% [markdown]
# ## plot feature importance

# %%
plot_model(tuned_gbr, plot = 'feature')

# %% [markdown]
# ## Avaliação do modelo

# %%
evaluate_model(tuned_gbr)

# %% [markdown]
# ## diabete - classificação

# %%
data = pd.read_csv('/home/silvio/dataset/pima-indians-diabetes.csv')

# %%
from pycaret.classification import *
clf1 = setup(data, target = 'Class', session_id=123, log_experiment=True, experiment_name='diabete')
# Out:
# <style  type="text/css" >
#     #T_76528486_bfc5_11eb_bce2_000c29a2246crow19_col1 {
#             background-color:  lightgreen;
#         }</style><table id="T_76528486_bfc5_11eb_bce2_000c29a2246c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_76528486_bfc5_11eb_bce2_000c29a2246clevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_76528486_bfc5_11eb_bce2_000c29a2246crow0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_76528486_bfc5_11eb_bce2_000c29a2246crow0_col1" class="data row0 col1" >123</td>
#             </tr>
#             <tr>
#                         <th id="T_76528486_bfc5_11eb_bce2_000c29a2246clevel0_row1" class="row_heading level0 row1" >1</th>
# ...

# %%
best_model = compare_models(fold=5)
# Out:
# <style  type="text/css" >
#     #T_850a30be_bfc5_11eb_bce2_000c29a2246c th {
#           text-align: left;
#     }    #T_850a30be_bfc5_11eb_bce2_000c29a2246crow0_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_850a30be_bfc5_11eb_bce2_000c29a2246crow0_col1 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_850a30be_bfc5_11eb_bce2_000c29a2246crow0_col2 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_850a30be_bfc5_11eb_bce2_000c29a2246crow0_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_850a30be_bfc5_11eb_bce2_000c29a2246crow0_col4 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_850a30be_bfc5_11eb_bce2_000c29a2246crow0_col5 {
#             text-align:  left;
#             text-align:  left;
# ...

# %%
rf = create_model('rf')
# Out:
# <style  type="text/css" >
#     #T_98112d48_bfc5_11eb_bce2_000c29a2246crow10_col0 {
#             background:  yellow;
#         }    #T_98112d48_bfc5_11eb_bce2_000c29a2246crow10_col1 {
#             background:  yellow;
#         }    #T_98112d48_bfc5_11eb_bce2_000c29a2246crow10_col2 {
#             background:  yellow;
#         }    #T_98112d48_bfc5_11eb_bce2_000c29a2246crow10_col3 {
#             background:  yellow;
#         }    #T_98112d48_bfc5_11eb_bce2_000c29a2246crow10_col4 {
#             background:  yellow;
#         }    #T_98112d48_bfc5_11eb_bce2_000c29a2246crow10_col5 {
#             background:  yellow;
#         }    #T_98112d48_bfc5_11eb_bce2_000c29a2246crow10_col6 {
#             background:  yellow;
# ...

# %%
tuned_rf = tune_model(rf)
# Out:
# <style  type="text/css" >
#     #T_c44315de_bfc5_11eb_bce2_000c29a2246crow10_col0 {
#             background:  yellow;
#         }    #T_c44315de_bfc5_11eb_bce2_000c29a2246crow10_col1 {
#             background:  yellow;
#         }    #T_c44315de_bfc5_11eb_bce2_000c29a2246crow10_col2 {
#             background:  yellow;
#         }    #T_c44315de_bfc5_11eb_bce2_000c29a2246crow10_col3 {
#             background:  yellow;
#         }    #T_c44315de_bfc5_11eb_bce2_000c29a2246crow10_col4 {
#             background:  yellow;
#         }    #T_c44315de_bfc5_11eb_bce2_000c29a2246crow10_col5 {
#             background:  yellow;
#         }    #T_c44315de_bfc5_11eb_bce2_000c29a2246crow10_col6 {
#             background:  yellow;
# ...

# %%
plot_model(rf)

# %%
plot_model(tuned_rf)

# %%
plot_model(rf, plot = 'confusion_matrix')

# %%
plot_model(tuned_rf, plot = 'confusion_matrix')

# %%
plot_model(rf, plot = 'feature')

# %%
evaluate_model(rf)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…
